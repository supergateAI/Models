# %% [markdown]
# <a href="https://colab.research.google.com/github/bala-codes/Yolo-v5_Object_Detection_Blood_Cell_Count/blob/master/codes/2.%20Yolo-v5%20BCC%20Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys, random
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install -qr '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/requirements.txt'  # install dependencies

# %% [markdown]
# #**NECCESSARY FILES FOR DETECTION AND LATER ADD THIS PATH TO THE SYSTEM VARIABLE**

# %% [markdown]
# <img src="https://github.com/bala-codes/Yolo-v5_Object_Detection_Blood_Cell_Count/blob/master/imgs/Dependency_files.PNG?raw=true" width="200%">

# %%
## Add the path where you have stored the neccessary supporting files to run detect.py ##
# sys.path.insert(0, '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/')
# print(sys.path)
# cwd = os.getcwd()
# print(cwd)
# Out:
# ['/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/', '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE_CODES/', '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE_CODES/', '', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython']
# /content

# %% [markdown]
# ## Single Image predictions

# %%
! ls ../imgs/images/valid/
# Out:
# 2018_0203_171530_040.JPG  2018_0211_172506_442.JPG  2020_0813_110534_368.JPG
# 2018_0203_171534_041.JPG  2018_0211_180846_104.JPG  2020_0813_110811_420.JPG
# 2018_0203_171649_066.JPG  2018_0211_180937_121.JPG  2020_0813_113559_912.JPG
# 2018_0203_171713_074.JPG  2018_0211_181204_170.JPG  2020_0813_114030_1002.JPG
# 2018_0203_171725_078.JPG  2018_0211_181219_175.JPG  2020_0813_114125_1020.JPG
# 2018_0203_171828_099.JPG  2018_0211_181246_184.JPG  2020_0813_114337_1064.JPG
# 2018_0203_171846_105.JPG  2020_0805_104653_079.JPG  2020_0813_114444_1086.JPG
# 2018_0211_171122_185.JPG  2020_0805_110118_284.JPG  2020_0813_115129_1172.JPG
# 2018_0211_171618_266.JPG  2020_0813_105132_130.JPG  2020_0813_115205_1184.JPG
# 2018_0211_171651_277.JPG  2020_0813_105932_248.JPG  2020_0813_115220_1189.JPG
# 2018_0211_172400_420.JPG  2020_0813_110331_327.JPG

# %%
## Beware the contents in the output folder will be deleted for every prediction

files = glob('inference/single_output/*')
for f in files:
    os.remove(f)
    
output = !python detect.py --source ../imgs/images/valid/2018_0211_181204_170.JPG --weights './runs/exp4_HOOK/weights/best_HOOK.pt' --output 'inference/single_output' --device 'cpu'

print(output)
# Out:
# ['Using CPU', '', 'Model Summary: 140 layers, 7.24652e+06 parameters, 6.61683e+06 gradients', "Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='cpu', img_size=640, iou_thres=0.5, output='inference/single_output', save_txt=False, source='../imgs/images/valid/2018_0211_181204_170.JPG', update=False, view_img=False, weights=['./runs/exp4_HOOK/weights/best_HOOK.pt'])", 'Fusing layers... ', 'image 1/1 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_181204_170.JPG: 512x640 1 hooks, Done. (0.093s)', 'Results saved to inference/single_output', 'Done. (0.220s)']

# %%
disp_images = glob('inference/single_output/*')
print(disp_images)
img = plt.imread(disp_images[0])
plt.imshow(img)
# Out:
# ['inference/single_output/2018_0211_181204_170.JPG']

# %% [markdown]
# ## Predict image in folders

# %%
output = !python detect.py --source ../imgs/images/valid/ --weights './runs/exp4_HOOK/weights/best_HOOK.pt' --output 'inference/output' --device 'cpu'
# output = !python '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/detect.py' --source '/content/inputs/' --weights '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/best_BCCM.pt' --output '/content/OUTPUTS/' --device 'cpu'

print(output)
# Out:
# ['Using CPU', '', 'Model Summary: 140 layers, 7.24652e+06 parameters, 6.61683e+06 gradients', "Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='cpu', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='../imgs/images/valid/', update=False, view_img=False, weights=['./runs/exp4_HOOK/weights/best_HOOK.pt'])", 'Fusing layers... ', 'image 1/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171530_040.JPG: 512x640 1 hooks, Done. (0.104s)', 'image 2/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171534_041.JPG: 512x640 1 hooks, Done. (0.076s)', 'image 3/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171649_066.JPG: 512x640 1 hooks, Done. (0.079s)', 'image 4/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171713_074.JPG: 512x640 2 hooks, Done. (0.076s)', 'image 5/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171725_078.JPG: 512x640 Done. (0.079s)', 'image 6/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171828_099.JPG: 512x640 1 hooks, Done. (0.077s)', 'image 7/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171846_105.JPG: 512x640 1 hooks, Done. (0.076s)', 'image 8/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_171122_185.JPG: 512x640 1 hooks, Done. (0.076s)', 'image 9/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_171618_266.JPG: 512x640 Done. (0.076s)', 'image 10/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_171651_277.JPG: 512x640 1 hooks, Done. (0.078s)', 'image 11/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_172400_420.JPG: 512x640 Done. (0.078s)', 'image 12/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_172506_442.JPG: 512x640 Done. (0.076s)', 'image 13/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_180846_104.JPG: 512x640 1 hooks, Done. (0.078s)', 'image 14/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_180937_121.JPG: 512x640 Done. (0.079s)', 'image 15/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_181204_170.JPG: 512x640 1 hooks, Done. (0.079s)', 'image 16/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_181219_175.JPG: 512x640 1 hooks, Done. (0.077s)', 'image 17/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_181246_184.JPG: 512x640 1 hooks, Done. (0.079s)', 'image 18/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0805_104653_079.JPG: 512x640 1 hooks, Done. (0.076s)', 'image 19/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0805_110118_284.JPG: 640x512 Done. (0.082s)', 'image 20/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_105132_130.JPG: 512x640 Done. (0.076s)', 'image 21/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_105932_248.JPG: 512x640 2 hooks, Done. (0.076s)', 'image 22/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_110331_327.JPG: 512x640 1 hooks, Done. (0.077s)', 'image 23/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_110534_368.JPG: 512x640 Done. (0.076s)', 'image 24/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_110811_420.JPG: 512x640 1 hooks, Done. (0.076s)', 'image 25/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_113559_912.JPG: 512x640 Done. (0.076s)', 'image 26/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_114030_1002.JPG: 512x640 1 hooks, Done. (0.076s)', 'image 27/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_114125_1020.JPG: 512x640 1 hooks, Done. (0.078s)', 'image 28/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_114337_1064.JPG: 512x640 1 hooks, Done. (0.078s)', 'image 29/32 /home/dayoung/ ...

# %%
output
# Out:
# ['Using CPU',
#  '',
#  'Model Summary: 140 layers, 7.24652e+06 parameters, 6.61683e+06 gradients',
#  "Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='cpu', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='../imgs/images/valid/', update=False, view_img=False, weights=['./runs/exp4_HOOK/weights/best_HOOK.pt'])",
#  'Fusing layers... ',
#  'image 1/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171530_040.JPG: 512x640 1 hooks, Done. (0.104s)',
#  'image 2/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171534_041.JPG: 512x640 1 hooks, Done. (0.076s)',
#  'image 3/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171649_066.JPG: 512x640 1 hooks, Done. (0.079s)',
#  'image 4/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171713_074.JPG: 512x640 2 hooks, Done. (0.076s)',
#  'image 5/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171725_078.JPG: 512x640 Done. (0.079s)',
#  'image 6/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171828_099.JPG: 512x640 1 hooks, Done. (0.077s)',
#  'image 7/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0203_171846_105.JPG: 512x640 1 hooks, Done. (0.076s)',
#  'image 8/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_171122_185.JPG: 512x640 1 hooks, Done. (0.076s)',
#  'image 9/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_171618_266.JPG: 512x640 Done. (0.076s)',
#  'image 10/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_171651_277.JPG: 512x640 1 hooks, Done. (0.078s)',
#  'image 11/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_172400_420.JPG: 512x640 Done. (0.078s)',
#  'image 12/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_172506_442.JPG: 512x640 Done. (0.076s)',
#  'image 13/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_180846_104.JPG: 512x640 1 hooks, Done. (0.078s)',
#  'image 14/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_180937_121.JPG: 512x640 Done. (0.079s)',
#  'image 15/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_181204_170.JPG: 512x640 1 hooks, Done. (0.079s)',
#  'image 16/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_181219_175.JPG: 512x640 1 hooks, Done. (0.077s)',
#  'image 17/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_181246_184.JPG: 512x640 1 hooks, Done. (0.079s)',
#  'image 18/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0805_104653_079.JPG: 512x640 1 hooks, Done. (0.076s)',
#  'image 19/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0805_110118_284.JPG: 640x512 Done. (0.082s)',
#  'image 20/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_105132_130.JPG: 512x640 Done. (0.076s)',
#  'image 21/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_105932_248.JPG: 512x640 2 hooks, Done. (0.076s)',
#  'image 22/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_110331_327.JPG: 512x640 1 hooks, Done. (0.077s)',
#  'image 23/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_110534_368.JPG: 512x640 Done. (0.076s)',
#  'image 24/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_110811_420.JPG: 512x640 1 hooks, Done. (0.076s)',
#  'image 25/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_113559_912.JPG: 512x640 Done. (0.076s)',
#  'image 26/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_114030_1002.JPG: 512x640 1 hooks, Done. (0.076s)',
#  'image 27/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_114125_1020.JPG: 512x640 1 hooks, Done. (0.078s)',
#  'image 28/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_114337_1064.JPG: 512x640 1 hooks, Done. (0.078s)',
#  'image 29/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_114444_1086.JPG: 512x640 Done. (0.079s)',
#  'image 30/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_115129_1172.JPG: 512x640 1 hooks, Done. (0.086s)',
#  'image 31/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_115205_1184.JPG: 512x640 2 hooks, Done. (0.078s)',
#  'image 32/32 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2020_0813_115220_1189.JPG: 512x640 2 hooks, Done. (0.077s)',
#  'Results saved to inference/output',
#  'Done. (4.873s)']

# %%
disp_images = glob('inference/output/*')

img = plt.imread(disp_images[5])
plt.imshow(img)

# %%
# img = plt.imread(disp_images[1])
# plt.imshow(img)
