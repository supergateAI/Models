# %% [markdown]
# <a href="https://colab.research.google.com/github/bala-codes/Yolo-v5_Object_Detection_Blood_Cell_Count/blob/master/codes/2.%20Yolo-v5%20BCC%20Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys, random
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# !pip install -qr '/content/drive/My Drive/Machine Learning Projects/YOLO/SOURCE/requirements.txt'  # install dependencies

# %%
# single detection
## Beware the contents in the output folder will be deleted for every prediction

files = glob('inference/single_output/*')
for f in files:
    os.remove(f)
    
output = !python detect.py --source ../data-preprocessed/hook_helmet/images/valid/2018_0211_181204_170.JPG --weights './runs/exp4_HOOK/weights/best_HOOK.pt' --output 'inference/single_output' --device 'cpu'

print(output)
# Out:
# ['Using CPU', '', 'Model Summary: 140 layers, 7.24652e+06 parameters, 6.61683e+06 gradients', "Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='cpu', img_size=640, iou_thres=0.5, output='inference/single_output', save_txt=False, source='../imgs/images/valid/2018_0211_181204_170.JPG', update=False, view_img=False, weights=['./runs/exp4_HOOK/weights/best_HOOK.pt'])", 'Fusing layers... ', 'image 1/1 /home/dayoung/dev/Yolo_Object_Detection/imgs/images/valid/2018_0211_181204_170.JPG: 512x640 1 hooks, Done. (0.093s)', 'Results saved to inference/single_output', 'Done. (0.220s)']

# %%
# multiple detection
# !python detect.py --source ../data-preprocessed/hook_helmet/images/valid/ --weights './runs/exp6_HookHelmet/weights/best_HookHelmet.pt' --output 'inference/output'
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='../data-preprocessed/hook_helmet/images/valid/', update=False, view_img=False, weights=['./runs/exp6_HookHelmet/weights/best_HookHelmet.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='GeForce RTX 2060', total_memory=5931MB)
#
# Fusing layers...
# Model Summary: 140 layers, 7.25461e+06 parameters, 6.61683e+06 gradients
# image 1/1873 /home/dayoung/dev/Models/Hook_Detection/data-preprocessed/hook_helmet/images/valid/2018_0203_170544_147.jpg: 512x640 1 helmets, 1 hooks, Done. (0.011s)
# image 2/1873 /home/dayoung/dev/Models/Hook_Detection/data-preprocessed/hook_helmet/images/valid/2018_0203_171516_035.jpg: 512x640 2 hooks, Done. (0.009s)
# image 3/1873 /home/dayoung/dev/Models/Hook_Detection/data-preprocessed/hook_helmet/images/valid/2018_0203_171530_040.jpg: 512x640 1 helmets, 2 hooks, Done. (0.008s)
# ...

# %%
## video detect
# !python detect.py --source ../hook_helmet_dataset/HookHelmet_test4.mp4 --weights './runs/exp6_HookHelmet/weights/best_HookHelmet.pt' --output 'inference/video_output'
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='inference/video_output', save_txt=False, source='../hook_helmet_dataset/HookHelmet_test4.mp4', update=False, view_img=False, weights=['./runs/exp6_HookHelmet/weights/best_HookHelmet.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='GeForce RTX 2060', total_memory=5931MB)
#
# Fusing layers...
# Model Summary: 140 layers, 7.25461e+06 parameters, 6.61683e+06 gradients
# video 1/1 (1/287) /home/dayoung/dev/Models/Hook_Detection/hook_helmet_dataset/HookHelmet_test4.mp4: 384x640 1 helmets, Done. (0.010s)
# video 1/1 (2/287) /home/dayoung/dev/Models/Hook_Detection/hook_helmet_dataset/HookHelmet_test4.mp4: 384x640 1 helmets, Done. (0.009s)
# video 1/1 (3/287) /home/dayoung/dev/Models/Hook_Detection/hook_helmet_dataset/HookHelmet_test4.mp4: 384x640 1 helmets, Done. (0.009s)
# ...

# %%
##examples
files = glob('../examples/*')
files
# Out:
# ['../examples/20200903_135256.mp4', '../examples/20200903_135254_HDR.jpg']

# %%
# !python detect.py --source ../examples/20200903_135256.mp4 --weights './runs/exp0_HELMET/weights/best_HELMET.pt' --output 'inference/example_output'
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='inference/example_output', save_txt=False, source='../examples/20200903_135256.mp4', update=False, view_img=False, weights=['./runs/exp0_HELMET/weights/best_HELMET.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='GeForce RTX 2060', total_memory=5931MB)
#
# Traceback (most recent call last):
#   File "detect.py", line 173, in <module>
#     detect()
#   File "detect.py", line 35, in detect
#     model = attempt_load(weights, map_location=device)  # load FP32 model
#   File "/home/dayoung/dev/Models/Hook_Detection/codes/models/experimental.py", line 137, in attempt_load
#     model.append(torch.load(w, map_location=map_location)['model'].float().fuse().eval())  # load FP32 model
#   File "/home/dayoung/anaconda3/envs/detect/lib/python3.8/site-packages/torch/serialization.py", line 571, in load
#     with _open_file_like(f, 'rb') as opened_file:
# ...

# %% [markdown]
# ### Detection result
# - hook : safty hook
# - helmet : helmet on
# - head : helmet off

# %%
# hook+helmet+head+person detection model
disp_images = glob('inference/output/2018*')
fig=plt.figure(figsize=(20, 28))
columns = 3
rows = 7
for i in range(1, columns*rows +1):
    img = np.random.choice(disp_images)
#     img = disp_images[i+4]
    img = plt.imread(img)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
# img = plt.imread(disp_images[1])
# plt.imshow(img)
